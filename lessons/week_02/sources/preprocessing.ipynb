# %% [markdown]
# # 1.0 An end-to-end classification problem (ETL)

# %% [markdown]
# ## 1.1 Dataset description

# %% [markdown]
# We'll be looking at individual income in the United States. The **data** is from the **1994 census**, and contains information on an individual's **marital status**, **age**, **type of work**, and more. The **target column**, or what we want to predict, is whether individuals make less than or equal to 50k a year, or more than **50k a year**.
#
# You can download the data from the [University of California, Irvine's website](http://archive.ics.uci.edu/ml/datasets/Adult).
#
# Let's take the following steps:
#
# 1. Load Libraries
# 2. Fetch Data, including EDA
# 3. Pre-procesing
# 4. Data Segregation
#
# <center><img width="600" src="https://drive.google.com/uc?export=view&id=1a-nyAPNPiVh-Xb2Pu2t2p-BhSvHJS0pO"></center>

# %% [markdown]
# ## 1.2 Install and load libraries

# %%
# !pip install wandb

# %%
import wandb
import pandas as pd

# %% [markdown]
# ## 1.3 Preprocessing

# %% [markdown]
# ### 1.3.1 Login wandb

# %%
# Login to Weights & Biases
# !wandb login --relogin
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ### 1.3.2 Artifacts

# %%
input_artifact="decision_tree/raw_data.csv:latest"
artifact_name="preprocessed_data.csv"
artifact_type="clean_data"
artifact_description="Data after preprocessing"

# %% [markdown]
# ### 1.3.3 Setup your wandb project and clean the dataset

# %% [markdown]
# After the fetch step the raw data artifact was generated.
# Now, we need to pre-processing the raw data to create a new artfiact (clean_data).

# %%
# create a new job_type
run = wandb.init(project="decision_tree", job_type="process_data")
# Out:
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220404_223353-n93uggvj</code>
# Syncing run <strong><a href="https://wandb.ai/ivanovitchm/decision_tree/runs/n93uggvj" target="_blank">likely-wind-6</a></strong> to <a href="https://wandb.ai/ivanovitchm/decision_tree" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# donwload the latest version of artifact raw_data.csv
artifact = run.use_artifact(input_artifact)

# create a dataframe from the artifact
df = pd.read_csv(artifact.file())

# %%
# Delete duplicated rows
df.drop_duplicates(inplace=True)

# Generate a "clean data file"
df.to_csv(artifact_name,index=False)

# %%
# Create a new artifact and configure with the necessary arguments
artifact = wandb.Artifact(name=artifact_name,
                          type=artifact_type,
                          description=artifact_description)
artifact.add_file(artifact_name)
# Out:
# <ManifestEntry digest: J1V627eFf/f14pxG4ZOYzg==>

# %%
# Upload the artifact to Wandb
run.log_artifact(artifact)

# %%
# close the run
# waiting a while after run the previous cell before execute this
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.633 MB of 3.633 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">likely-wind-6</strong>: <a href="https://wandb.ai/ivanovitchm/decision_tree/runs/n93uggvj" target="_blank">https://wandb.ai/ivanovitchm/decision_tree/runs/n93uggvj</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220404_223353-n93uggvj/logs</code>
