# %% [markdown]
# # A brief recap about DL Pipeline

# %% [markdown]
# - Define the task
#   - Frame the problem
#   - Collect a dataset
#   - Understand your data
#   - Choose a measure of success
# - Develop a model
#   - Prepare the data
#   - Choose an evaluation protocol
#   - Beat a baseline
#   - Scale up: develop a model that overfits
#   - Regularize and tune your model
# - Deploy your model
#   - Explain your work to stakeholders and set expectations
#     - Ship an inference model
#     - Deploying a model as a rest API
#     - Deploying a model on device
#     - Deploying a model in the browser
#   - Monitor your model in the wild
#   - Maintain your model

# %% [markdown]
# # 1.0 Baseline Model

# %% [markdown]
# ## 1.1 Import Libraries

# %% [markdown]
# Install and import the Keras Tuner.

# %%
# pip install -q (quiet)
# !pip install git+https://github.com/keras-team/keras-tuner.git -q
# Out:
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import h5py
import time
import datetime
import pytz
import IPython
import kerastuner as kt

# %%
print('TF version:', tf.__version__)
print('KT version:', kt.__version__)
print('GPU devices:', tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.3.0
# KT version: 1.0.2rc2
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1.2 Utils Functions

# %%
def load_dataset():
    # load the train data
    train_dataset = h5py.File('train_catvnoncat.h5', "r")

    # your train set features
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) 

    # your train set labels
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) 

    
    # load the test data
    test_dataset = h5py.File('test_catvnoncat.h5', "r")

    # your test set features
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) 

    # your test set labels  
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) 

    # the list of classes
    classes = np.array(test_dataset["list_classes"][:]) 

    # reshape the test data
    train_set_y_orig = train_set_y_orig.reshape((train_set_y_orig.shape[0],1))
    test_set_y_orig = test_set_y_orig.reshape((test_set_y_orig.shape[0],1))

    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %% [markdown]
# ## 1.3 Load Dataset

# %%
# Loading the data (cat/non-cat)
train_set_x_orig, train_y, test_set_x_orig, test_y, classes = load_dataset()

# %%
# Reshape the training and test examples
train_set_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0],-1)
test_set_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0],-1)

# Standardize the dataset
train_x = train_set_x_flatten/255
test_x = test_set_x_flatten/255

# %%
print ("train_x shape: " + str(train_x.shape))
print ("train_y shape: " + str(train_y.shape))
print ("test_x  shape: " + str(test_x.shape))
print ("test_y  shape: " + str(test_y.shape))
# Out:
# train_x shape: (209, 12288)
# train_y shape: (209, 1)
# test_x  shape: (50, 12288)
# test_y  shape: (50, 1)

# %%
# visualize a sample data
index = 13
plt.imshow(train_set_x_orig[index])

# %% [markdown]
# ## 1.4 Model

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):

  def on_train_begin(self, batch, logs=None):
    self.begins = time.time()
    print('Training: begins at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%Y-%m-%d %H:%M:%S")))

  def on_train_end(self, logs=None):
    print('Training: ends at {}'.format(datetime.datetime.now(pytz.timezone('America/Fortaleza')).strftime("%Y-%m-%d %H:%M:%S")))
    print('Duration: {}s'.format(time.time() - self.begins))

# %%
# Instantiate a simple classification model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(8, activation=tf.nn.relu, dtype='float64'),
  tf.keras.layers.Dense(8, activation=tf.nn.relu, dtype='float64'),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, dtype='float64')
])

# Instantiate a logistic loss function that expects integer targets.
loss = tf.keras.losses.BinaryCrossentropy()

# Instantiate an accuracy metric.
accuracy = tf.keras.metrics.BinaryAccuracy()

# Instantiate an optimizer.
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

# configure the optimizer, loss, and metrics to monitor.
model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])

# training 
history = model.fit(x=train_x,
                    y=train_y,
                    batch_size=32,
                    epochs=500,
                    validation_data=(test_x,test_y),
                    callbacks=[MyCustomCallback()],
                    verbose=1)
# Out:
# Training: begins at 2020-09-21 16:11:36
# Epoch 1/500
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6837 - binary_accuracy: 0.5789 - val_loss: 0.7348 - val_binary_accuracy: 0.3600
# Epoch 2/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6619 - binary_accuracy: 0.6411 - val_loss: 0.7726 - val_binary_accuracy: 0.3000
# Epoch 3/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6529 - binary_accuracy: 0.6555 - val_loss: 0.8008 - val_binary_accuracy: 0.3000
# Epoch 4/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6488 - binary_accuracy: 0.6555 - val_loss: 0.8123 - val_binary_accuracy: 0.3200
# Epoch 5/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6437 - binary_accuracy: 0.6651 - val_loss: 0.8174 - val_binary_accuracy: 0.3200
# Epoch 6/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6414 - binary_accuracy: 0.6651 - val_loss: 0.8089 - val_binary_accuracy: 0.3400
# Epoch 7/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6402 - binary_accuracy: 0.6699 - val_loss: 0.8174 - val_binary_accuracy: 0.3400
# Epoch 8/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6374 - binary_accuracy: 0.6699 - val_loss: 0.8258 - val_binary_accuracy: 0.3200
# Epoch 9/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6353 - binary_accuracy: 0.6651 - val_loss: 0.8175 - val_binary_accuracy: 0.3200
# Epoch 10/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6337 - binary_accuracy: 0.6699 - val_loss: 0.8052 - val_binary_accuracy: 0.3000
# Epoch 11/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6305 - binary_accuracy: 0.6603 - val_loss: 0.7992 - val_binary_accuracy: 0.3000
# Epoch 12/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6303 - binary_accuracy: 0.6746 - val_loss: 0.8137 - val_binary_accuracy: 0.3400
# Epoch 13/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6276 - binary_accuracy: 0.6699 - val_loss: 0.8242 - val_binary_accuracy: 0.3400
# Epoch 14/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6239 - binary_accuracy: 0.6794 - val_loss: 0.7800 - val_binary_accuracy: 0.3800
# Epoch 15/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6245 - binary_accuracy: 0.6842 - val_loss: 0.8305 - val_binary_accuracy: 0.3800
# Epoch 16/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6208 - binary_accuracy: 0.6794 - val_loss: 0.8296 - val_binary_accuracy: 0.3800
# Epoch 17/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6189 - binary_accuracy: 0.6746 - val_loss: 0.8223 - val_binary_accuracy: 0.3800
# Epoch 18/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6181 - binary_accuracy: 0.6794 - val_loss: 0.8322 - val_binary_accuracy: 0.3800
# Epoch 19/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6156 - binary_accuracy: 0.6890 - val_loss: 0.8337 - val_binary_accuracy: 0.3800
# Epoch 20/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6143 - binary_accuracy: 0.6794 - val_loss: 0.8054 - val_binary_accuracy: 0.3800
# Epoch 21/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6117 - binary_accuracy: 0.6794 - val_loss: 0.8071 - val_binary_accuracy: 0.4200
# Epoch 22/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6109 - binary_accuracy: 0.6890 - val_loss: 0.7878 - val_binary_accuracy: 0.4200
# Epoch 23/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6074 - binary_accuracy: 0.6938 - val_loss: 0.8200 - val_binary_accuracy: 0.4200
# Epoch 24/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6065 - binary_accuracy: 0.6842 - val_loss: 0.7966 - val_binary_accuracy: 0.4400
# Epoch 25/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6053 - binary_accuracy: 0.6938 - val_loss: 0.8035 - val_binary_accuracy: 0.4200
# Epoch 26/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6017 - binary_accuracy: 0.6842 - val_loss: 0.8049 - val_binary_accuracy: 0.4200
# Epoch 27/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5996 - binary_accuracy: 0.6986 - val_loss: 0.8100 - val_binary_accuracy: 0.4200
# Epoch 28/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5989 - binary_accuracy: 0.6890 - val_loss: 0.8049 - val_binary_accuracy: 0.4200
# Epoch 29/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5952 - binary_accuracy: 0.6986 - val_loss: 0.7916 - val_binary_accuracy: 0.4600
# Epoch 30/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5944 - binary_accuracy: 0.6986 - val_loss: 0.7548 - val_binary_accuracy: 0.4600
# Epoch 31/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5932 - binary_accuracy: 0.7129 - val_loss: 0.7939 - val_binary_accuracy: 0.4600
# Epoch 32/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5938 - binary_accuracy: 0.6938 - val_loss: 0.8003 - val_binary_accuracy: 0.4600
# Epoch 33/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5894 - binary_accuracy: 0.6986 - val_loss: 0.7546 - val_binary_accuracy: 0.4600
# Epoch 34/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5876 - binary_accuracy: 0.7129 - val_loss: 0.7695 - val_binary_accuracy: 0.4800
# Epoch 35/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5852 - binary_accuracy: 0.7081 - val_loss: 0.7782 - val_binary_accuracy: 0.4600
# Epoch 36/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5849 - binary_accuracy: 0.7177 - val_loss: 0.7724 - val_binary_accuracy: 0.4600
# Epoch 37/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5842 - binary_accuracy: 0.7033 - val_loss: 0.7451 - val_binary_accuracy: 0.4600
# Epoch 38/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5834 - binary_accuracy: 0.7081 - val_loss: 0.7753 - val_binary_accuracy: 0.4600
# Epoch 39/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5808 - binary_accuracy: 0.7129 - val_loss: 0.7724 - val_binary_accuracy: 0.4600
# Epoch 40/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5779 - binary_accuracy: 0.7177 - val_loss: 0.7784 - val_binary_accuracy: 0.4600
# Epoch 41/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5763 - binary_accuracy: 0.7177 - val_loss: 0.7951 - val_binary_accuracy: 0.4600
# Epoch 42/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5753 - binary_accuracy: 0.7129 - val_loss: 0.7645 - val_binary_accuracy: 0.4800
# Epoch 43/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5719 - binary_accuracy: 0.7273 - val_loss: 0.7746 - val_binary_accuracy: 0.4800
# Epoch 44/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5705 - binary_accuracy: 0.7321 - val_loss: 0.7818 - val_binary_accuracy: 0.4600
# Epoch 45/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5710 - binary_accuracy: 0.7129 - val_loss: 0.7216 - val_binary_accuracy: 0.5800
# Epoch 46/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5682 - binary_accuracy: 0.7416 - val_loss: 0.7811 - val_binary_accuracy: 0.4600
# Epoch 47/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5672 - binary_accuracy: 0.7273 - val_loss: 0.7681 - val_binary_accuracy: 0.4600
# Epoch 48/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5688 - binary_accuracy: 0.7321 - val_loss: 0.7953 - val_binary_accuracy: 0.4600
# Epoch 49/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5643 - binary_accuracy: 0.7177 - val_loss: 0.7556 - val_binary_accuracy: 0.5000
# Epoch 50/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5621 - binary_accuracy: 0.7321 - val_loss: 0.7985 - val_binary_accuracy: 0.4600
# Epoch 51/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5628 - binary_accuracy: 0.7273 - val_loss: 0.7714 - val_binary_accuracy: 0.4800
# Epoch 52/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5591 - binary_accuracy: 0.7368 - val_loss: 0.7585 - val_binary_accuracy: 0.5000
# Epoch 53/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5573 - binary_accuracy: 0.7416 - val_loss: 0.7507 - val_binary_accuracy: 0.5200
# Epoch 54/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5597 - binary_accuracy: 0.7416 - val_loss: 0.7586 - val_binary_accuracy: 0.4800
# Epoch 55/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5585 - binary_accuracy: 0.7321 - val_loss: 0.7601 - val_binary_accuracy: 0.4800
# Epoch 56/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5533 - binary_accuracy: 0.7703 - val_loss: 0.7735 - val_binary_accuracy: 0.4600
# Epoch 57/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5525 - binary_accuracy: 0.7273 - val_loss: 0.7262 - val_binary_accuracy: 0.6200
# Epoch 58/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5528 - binary_accuracy: 0.7464 - val_loss: 0.7559 - val_binary_accuracy: 0.5000
# Epoch 59/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5501 - binary_accuracy: 0.7464 - val_loss: 0.7718 - val_binary_accuracy: 0.4800
# Epoch 60/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5545 - binary_accuracy: 0.7368 - val_loss: 0.7677 - val_binary_accuracy: 0.4800
# Epoch 61/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5461 - binary_accuracy: 0.7416 - val_loss: 0.7121 - val_binary_accuracy: 0.6000
# Epoch 62/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5473 - binary_accuracy: 0.7512 - val_loss: 0.7337 - val_binary_accuracy: 0.6000
# Epoch 63/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5467 - binary_accuracy: 0.7321 - val_loss: 0.7321 - val_binary_accuracy: 0.6200
# Epoch 64/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5443 - binary_accuracy: 0.7608 - val_loss: 0.7333 - val_binary_accuracy: 0.6000
# Epoch 65/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5413 - binary_accuracy: 0.7608 - val_loss: 0.7523 - val_binary_accuracy: 0.5200
# Epoch 66/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5441 - binary_accuracy: 0.7512 - val_loss: 0.7705 - val_binary_accuracy: 0.4800
# Epoch 67/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5398 - binary_accuracy: 0.7464 - val_loss: 0.7256 - val_binary_accuracy: 0.6400
# Epoch 68/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5394 - binary_accuracy: 0.7608 - val_loss: 0.7357 - val_binary_accuracy: 0.5800
# Epoch 69/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5372 - binary_accuracy: 0.7656 - val_loss: 0.7366 - val_binary_accuracy: 0.5600
# Epoch 70/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5354 - binary_accuracy: 0.7703 - val_loss: 0.7531 - val_binary_accuracy: 0.4800
# Epoch 71/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5341 - binary_accuracy: 0.7608 - val_loss: 0.7169 - val_binary_accuracy: 0.6000
# Epoch 72/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5352 - binary_accuracy: 0.7751 - val_loss: 0.7129 - val_binary_accuracy: 0.6000
# Epoch 73/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5317 - binary_accuracy: 0.7751 - val_loss: 0.7539 - val_binary_accuracy: 0.4800
# Epoch 74/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5341 - binary_accuracy: 0.7656 - val_loss: 0.7651 - val_binary_accuracy: 0.4800
# Epoch 75/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5305 - binary_accuracy: 0.7703 - val_loss: 0.7739 - val_binary_accuracy: 0.4800
# Epoch 76/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5281 - binary_accuracy: 0.7464 - val_loss: 0.7227 - val_binary_accuracy: 0.6200
# Epoch 77/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5279 - binary_accuracy: 0.7751 - val_loss: 0.7439 - val_binary_accuracy: 0.5600
# Epoch 78/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5253 - binary_accuracy: 0.7656 - val_loss: 0.7435 - val_binary_accuracy: 0.5400
# Epoch 79/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5236 - binary_accuracy: 0.7703 - val_loss: 0.7316 - val_binary_accuracy: 0.6200
# Epoch 80/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5223 - binary_accuracy: 0.7799 - val_loss: 0.7466 - val_binary_accuracy: 0.5200
# Epoch 81/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5215 - binary_accuracy: 0.7751 - val_loss: 0.7299 - val_binary_accuracy: 0.6200
# Epoch 82/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5183 - binary_accuracy: 0.7751 - val_loss: 0.7070 - val_binary_accuracy: 0.6000
# Epoch 83/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5243 - binary_accuracy: 0.7751 - val_loss: 0.7394 - val_binary_accuracy: 0.5600
# Epoch 84/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5164 - binary_accuracy: 0.7656 - val_loss: 0.7171 - val_binary_accuracy: 0.6000
# Epoch 85/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5199 - binary_accuracy: 0.7751 - val_loss: 0.7144 - val_binary_accuracy: 0.6000
# Epoch 86/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5158 - binary_accuracy: 0.7751 - val_loss: 0.7279 - val_binary_accuracy: 0.6400
# Epoch 87/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5150 - binary_accuracy: 0.7703 - val_loss: 0.7236 - val_binary_accuracy: 0.6200
# Epoch 88/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5119 - binary_accuracy: 0.7847 - val_loss: 0.7056 - val_binary_accuracy: 0.6000
# Epoch 89/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5131 - binary_accuracy: 0.7847 - val_loss: 0.7364 - val_binary_accuracy: 0.6000
# Epoch 90/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5114 - binary_accuracy: 0.7847 - val_loss: 0.7231 - val_binary_accuracy: 0.6000
# Epoch 91/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5095 - binary_accuracy: 0.7847 - val_loss: 0.7350 - val_binary_accuracy: 0.6000
# Epoch 92/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5091 - binary_accuracy: 0.7751 - val_loss: 0.7134 - val_binary_accuracy: 0.6400
# Epoch 93/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5085 - binary_accuracy: 0.7847 - val_loss: 0.7323 - val_binary_accuracy: 0.5800
# Epoch 94/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5044 - binary_accuracy: 0.7799 - val_loss: 0.7242 - val_binary_accuracy: 0.6000
# Epoch 95/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5053 - binary_accuracy: 0.7799 - val_loss: 0.6933 - val_binary_accuracy: 0.6000
# Epoch 96/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5045 - binary_accuracy: 0.7799 - val_loss: 0.7038 - val_binary_accuracy: 0.6200
# Epoch 97/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5019 - binary_accuracy: 0.7895 - val_loss: 0.7074 - val_binary_accuracy: 0.6000
# Epoch 98/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5009 - binary_accuracy: 0.7799 - val_loss: 0.7322 - val_binary_accuracy: 0.6000
# Epoch 99/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5014 - binary_accuracy: 0.7847 - val_loss: 0.7264 - val_binary_accuracy: 0.6400
# Epoch 100/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4977 - binary_accuracy: 0.7847 - val_loss: 0.7314 - val_binary_accuracy: 0.6000
# Epoch 101/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4999 - binary_accuracy: 0.7895 - val_loss: 0.7178 - val_binary_accuracy: 0.6200
# Epoch 102/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4984 - binary_accuracy: 0.8038 - val_loss: 0.7365 - val_binary_accuracy: 0.5800
# Epoch 103/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4951 - binary_accuracy: 0.7751 - val_loss: 0.7276 - val_binary_accuracy: 0.6000
# Epoch 104/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4944 - binary_accuracy: 0.7847 - val_loss: 0.7211 - val_binary_accuracy: 0.6200
# Epoch 105/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4929 - binary_accuracy: 0.8038 - val_loss: 0.7353 - val_binary_accuracy: 0.5800
# Epoch 106/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4946 - binary_accuracy: 0.7847 - val_loss: 0.7007 - val_binary_accuracy: 0.6400
# Epoch 107/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4946 - binary_accuracy: 0.7990 - val_loss: 0.6982 - val_binary_accuracy: 0.6400
# Epoch 108/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4896 - binary_accuracy: 0.7943 - val_loss: 0.7313 - val_binary_accuracy: 0.5800
# Epoch 109/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4879 - binary_accuracy: 0.7943 - val_loss: 0.7261 - val_binary_accuracy: 0.6000
# Epoch 110/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4877 - binary_accuracy: 0.8038 - val_loss: 0.7016 - val_binary_accuracy: 0.6400
# Epoch 111/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4849 - binary_accuracy: 0.8134 - val_loss: 0.7414 - val_binary_accuracy: 0.6000
# Epoch 112/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4866 - binary_accuracy: 0.7895 - val_loss: 0.6920 - val_binary_accuracy: 0.6200
# Epoch 113/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4859 - binary_accuracy: 0.8086 - val_loss: 0.6909 - val_binary_accuracy: 0.6600
# Epoch 114/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4839 - binary_accuracy: 0.8086 - val_loss: 0.7255 - val_binary_accuracy: 0.6000
# Epoch 115/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4813 - binary_accuracy: 0.7943 - val_loss: 0.7155 - val_binary_accuracy: 0.6200
# Epoch 116/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4821 - binary_accuracy: 0.8038 - val_loss: 0.7368 - val_binary_accuracy: 0.5600
# Epoch 117/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4799 - binary_accuracy: 0.7990 - val_loss: 0.7012 - val_binary_accuracy: 0.6200
# Epoch 118/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4781 - binary_accuracy: 0.8038 - val_loss: 0.6997 - val_binary_accuracy: 0.6400
# Epoch 119/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4775 - binary_accuracy: 0.7990 - val_loss: 0.6909 - val_binary_accuracy: 0.6400
# Epoch 120/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4760 - binary_accuracy: 0.8086 - val_loss: 0.7037 - val_binary_accuracy: 0.6400
# Epoch 121/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4771 - binary_accuracy: 0.8134 - val_loss: 0.6796 - val_binary_accuracy: 0.6600
# Epoch 122/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4760 - binary_accuracy: 0.8230 - val_loss: 0.7258 - val_binary_accuracy: 0.6000
# Epoch 123/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4747 - binary_accuracy: 0.7990 - val_loss: 0.6826 - val_binary_accuracy: 0.6600
# Epoch 124/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4763 - binary_accuracy: 0.8086 - val_loss: 0.6929 - val_binary_accuracy: 0.6600
# Epoch 125/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4734 - binary_accuracy: 0.8134 - val_loss: 0.6942 - val_binary_accuracy: 0.6600
# Epoch 126/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4684 - binary_accuracy: 0.8134 - val_loss: 0.6847 - val_binary_accuracy: 0.6600
# Epoch 127/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4687 - binary_accuracy: 0.8230 - val_loss: 0.7084 - val_binary_accuracy: 0.6200
# Epoch 128/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4669 - binary_accuracy: 0.8134 - val_loss: 0.7112 - val_binary_accuracy: 0.6200
# Epoch 129/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4672 - binary_accuracy: 0.8134 - val_loss: 0.6971 - val_binary_accuracy: 0.6400
# Epoch 130/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4628 - binary_accuracy: 0.8086 - val_loss: 0.6524 - val_binary_accuracy: 0.6800
# Epoch 131/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4702 - binary_accuracy: 0.8182 - val_loss: 0.7023 - val_binary_accuracy: 0.6400
# Epoch 132/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4630 - binary_accuracy: 0.8086 - val_loss: 0.6780 - val_binary_accuracy: 0.6600
# Epoch 133/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4609 - binary_accuracy: 0.8230 - val_loss: 0.6609 - val_binary_accuracy: 0.6600
# Epoch 134/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4592 - binary_accuracy: 0.8230 - val_loss: 0.6975 - val_binary_accuracy: 0.6400
# Epoch 135/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4592 - binary_accuracy: 0.8230 - val_loss: 0.6890 - val_binary_accuracy: 0.6600
# Epoch 136/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4585 - binary_accuracy: 0.8230 - val_loss: 0.7035 - val_binary_accuracy: 0.6400
# Epoch 137/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4618 - binary_accuracy: 0.8134 - val_loss: 0.6895 - val_binary_accuracy: 0.6800
# Epoch 138/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4574 - binary_accuracy: 0.8230 - val_loss: 0.6515 - val_binary_accuracy: 0.6600
# Epoch 139/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4566 - binary_accuracy: 0.8230 - val_loss: 0.6784 - val_binary_accuracy: 0.6600
# Epoch 140/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4551 - binary_accuracy: 0.8278 - val_loss: 0.7007 - val_binary_accuracy: 0.6600
# Epoch 141/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4543 - binary_accuracy: 0.8230 - val_loss: 0.7095 - val_binary_accuracy: 0.6200
# Epoch 142/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4549 - binary_accuracy: 0.8038 - val_loss: 0.6692 - val_binary_accuracy: 0.6600
# Epoch 143/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4504 - binary_accuracy: 0.8278 - val_loss: 0.6838 - val_binary_accuracy: 0.6800
# Epoch 144/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4495 - binary_accuracy: 0.8325 - val_loss: 0.7264 - val_binary_accuracy: 0.6000
# Epoch 145/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4513 - binary_accuracy: 0.8230 - val_loss: 0.6854 - val_binary_accuracy: 0.6800
# Epoch 146/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4493 - binary_accuracy: 0.8230 - val_loss: 0.7147 - val_binary_accuracy: 0.6000
# Epoch 147/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4511 - binary_accuracy: 0.8278 - val_loss: 0.7047 - val_binary_accuracy: 0.6400
# Epoch 148/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4456 - binary_accuracy: 0.8230 - val_loss: 0.6940 - val_binary_accuracy: 0.6800
# Epoch 149/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4458 - binary_accuracy: 0.8278 - val_loss: 0.6773 - val_binary_accuracy: 0.6800
# Epoch 150/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4435 - binary_accuracy: 0.8373 - val_loss: 0.6709 - val_binary_accuracy: 0.6600
# Epoch 151/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4432 - binary_accuracy: 0.8278 - val_loss: 0.6548 - val_binary_accuracy: 0.6600
# Epoch 152/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4407 - binary_accuracy: 0.8373 - val_loss: 0.6736 - val_binary_accuracy: 0.6800
# Epoch 153/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4389 - binary_accuracy: 0.8278 - val_loss: 0.6737 - val_binary_accuracy: 0.6800
# Epoch 154/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4409 - binary_accuracy: 0.8230 - val_loss: 0.6727 - val_binary_accuracy: 0.6800
# Epoch 155/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4375 - binary_accuracy: 0.8230 - val_loss: 0.6943 - val_binary_accuracy: 0.6400
# Epoch 156/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4375 - binary_accuracy: 0.8278 - val_loss: 0.6572 - val_binary_accuracy: 0.6600
# Epoch 157/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4360 - binary_accuracy: 0.8325 - val_loss: 0.6472 - val_binary_accuracy: 0.6800
# Epoch 158/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4404 - binary_accuracy: 0.8325 - val_loss: 0.7093 - val_binary_accuracy: 0.6200
# Epoch 159/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4345 - binary_accuracy: 0.8278 - val_loss: 0.6546 - val_binary_accuracy: 0.6600
# Epoch 160/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4347 - binary_accuracy: 0.8421 - val_loss: 0.6824 - val_binary_accuracy: 0.6800
# Epoch 161/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4324 - binary_accuracy: 0.8373 - val_loss: 0.6924 - val_binary_accuracy: 0.6600
# Epoch 162/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4320 - binary_accuracy: 0.8278 - val_loss: 0.6642 - val_binary_accuracy: 0.6800
# Epoch 163/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4312 - binary_accuracy: 0.8421 - val_loss: 0.6564 - val_binary_accuracy: 0.6600
# Epoch 164/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4289 - binary_accuracy: 0.8373 - val_loss: 0.6357 - val_binary_accuracy: 0.6800
# Epoch 165/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4272 - binary_accuracy: 0.8612 - val_loss: 0.6667 - val_binary_accuracy: 0.6600
# Epoch 166/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4268 - binary_accuracy: 0.8373 - val_loss: 0.6781 - val_binary_accuracy: 0.6800
# Epoch 167/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4277 - binary_accuracy: 0.8469 - val_loss: 0.6519 - val_binary_accuracy: 0.6600
# Epoch 168/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4239 - binary_accuracy: 0.8469 - val_loss: 0.6762 - val_binary_accuracy: 0.6600
# Epoch 169/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4255 - binary_accuracy: 0.8373 - val_loss: 0.6514 - val_binary_accuracy: 0.6600
# Epoch 170/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4269 - binary_accuracy: 0.8421 - val_loss: 0.6395 - val_binary_accuracy: 0.6800
# Epoch 171/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4227 - binary_accuracy: 0.8517 - val_loss: 0.6406 - val_binary_accuracy: 0.6600
# Epoch 172/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4218 - binary_accuracy: 0.8565 - val_loss: 0.6707 - val_binary_accuracy: 0.6600
# Epoch 173/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4198 - binary_accuracy: 0.8421 - val_loss: 0.6602 - val_binary_accuracy: 0.6800
# Epoch 174/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4195 - binary_accuracy: 0.8373 - val_loss: 0.6144 - val_binary_accuracy: 0.6800
# Epoch 175/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4304 - binary_accuracy: 0.8517 - val_loss: 0.6501 - val_binary_accuracy: 0.6600
# Epoch 176/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4217 - binary_accuracy: 0.8565 - val_loss: 0.6424 - val_binary_accuracy: 0.6600
# Epoch 177/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4198 - binary_accuracy: 0.8325 - val_loss: 0.6528 - val_binary_accuracy: 0.6600
# Epoch 178/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4135 - binary_accuracy: 0.8565 - val_loss: 0.6639 - val_binary_accuracy: 0.6600
# Epoch 179/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4156 - binary_accuracy: 0.8421 - val_loss: 0.6429 - val_binary_accuracy: 0.6600
# Epoch 180/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4116 - binary_accuracy: 0.8612 - val_loss: 0.6364 - val_binary_accuracy: 0.6600
# Epoch 181/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4125 - binary_accuracy: 0.8612 - val_loss: 0.6414 - val_binary_accuracy: 0.6600
# Epoch 182/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4111 - binary_accuracy: 0.8517 - val_loss: 0.6330 - val_binary_accuracy: 0.6600
# Epoch 183/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4114 - binary_accuracy: 0.8565 - val_loss: 0.6294 - val_binary_accuracy: 0.6600
# Epoch 184/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4070 - binary_accuracy: 0.8708 - val_loss: 0.6304 - val_binary_accuracy: 0.6800
# Epoch 185/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4071 - binary_accuracy: 0.8660 - val_loss: 0.6652 - val_binary_accuracy: 0.6600
# Epoch 186/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4116 - binary_accuracy: 0.8469 - val_loss: 0.6538 - val_binary_accuracy: 0.6600
# Epoch 187/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4039 - binary_accuracy: 0.8565 - val_loss: 0.6573 - val_binary_accuracy: 0.6600
# Epoch 188/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4053 - binary_accuracy: 0.8469 - val_loss: 0.6166 - val_binary_accuracy: 0.6800
# Epoch 189/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4050 - binary_accuracy: 0.8804 - val_loss: 0.6547 - val_binary_accuracy: 0.6800
# Epoch 190/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4023 - binary_accuracy: 0.8660 - val_loss: 0.6620 - val_binary_accuracy: 0.6800
# Epoch 191/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4024 - binary_accuracy: 0.8660 - val_loss: 0.6747 - val_binary_accuracy: 0.6800
# Epoch 192/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4008 - binary_accuracy: 0.8517 - val_loss: 0.6486 - val_binary_accuracy: 0.6600
# Epoch 193/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4017 - binary_accuracy: 0.8708 - val_loss: 0.6521 - val_binary_accuracy: 0.6600
# Epoch 194/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3978 - binary_accuracy: 0.8612 - val_loss: 0.6538 - val_binary_accuracy: 0.6600
# Epoch 195/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3974 - binary_accuracy: 0.8612 - val_loss: 0.6557 - val_binary_accuracy: 0.6600
# Epoch 196/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3965 - binary_accuracy: 0.8612 - val_loss: 0.6671 - val_binary_accuracy: 0.6600
# Epoch 197/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3958 - binary_accuracy: 0.8517 - val_loss: 0.6415 - val_binary_accuracy: 0.6600
# Epoch 198/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3945 - binary_accuracy: 0.8708 - val_loss: 0.6472 - val_binary_accuracy: 0.6800
# Epoch 199/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3927 - binary_accuracy: 0.8565 - val_loss: 0.6300 - val_binary_accuracy: 0.7000
# Epoch 200/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3933 - binary_accuracy: 0.8708 - val_loss: 0.6291 - val_binary_accuracy: 0.6600
# Epoch 201/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3884 - binary_accuracy: 0.8708 - val_loss: 0.6050 - val_binary_accuracy: 0.6800
# Epoch 202/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3944 - binary_accuracy: 0.8708 - val_loss: 0.6304 - val_binary_accuracy: 0.6800
# Epoch 203/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3888 - binary_accuracy: 0.8660 - val_loss: 0.6594 - val_binary_accuracy: 0.6600
# Epoch 204/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3903 - binary_accuracy: 0.8612 - val_loss: 0.6136 - val_binary_accuracy: 0.6800
# Epoch 205/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3886 - binary_accuracy: 0.8708 - val_loss: 0.6275 - val_binary_accuracy: 0.6600
# Epoch 206/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3850 - binary_accuracy: 0.8947 - val_loss: 0.6308 - val_binary_accuracy: 0.6600
# Epoch 207/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3859 - binary_accuracy: 0.8756 - val_loss: 0.6013 - val_binary_accuracy: 0.6800
# Epoch 208/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3875 - binary_accuracy: 0.8947 - val_loss: 0.6306 - val_binary_accuracy: 0.6600
# Epoch 209/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3844 - binary_accuracy: 0.8804 - val_loss: 0.6543 - val_binary_accuracy: 0.6600
# Epoch 210/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3843 - binary_accuracy: 0.8565 - val_loss: 0.6267 - val_binary_accuracy: 0.6600
# Epoch 211/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3809 - binary_accuracy: 0.8804 - val_loss: 0.6299 - val_binary_accuracy: 0.6600
# Epoch 212/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3806 - binary_accuracy: 0.9091 - val_loss: 0.6455 - val_binary_accuracy: 0.6800
# Epoch 213/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3783 - binary_accuracy: 0.8660 - val_loss: 0.6207 - val_binary_accuracy: 0.6600
# Epoch 214/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3780 - binary_accuracy: 0.8804 - val_loss: 0.6234 - val_binary_accuracy: 0.6800
# Epoch 215/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3790 - binary_accuracy: 0.8852 - val_loss: 0.6340 - val_binary_accuracy: 0.6600
# Epoch 216/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3771 - binary_accuracy: 0.8756 - val_loss: 0.6317 - val_binary_accuracy: 0.6600
# Epoch 217/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3749 - binary_accuracy: 0.8804 - val_loss: 0.6208 - val_binary_accuracy: 0.6600
# Epoch 218/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3754 - binary_accuracy: 0.8756 - val_loss: 0.6225 - val_binary_accuracy: 0.6600
# Epoch 219/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3755 - binary_accuracy: 0.8852 - val_loss: 0.6270 - val_binary_accuracy: 0.6600
# Epoch 220/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3723 - binary_accuracy: 0.8660 - val_loss: 0.6096 - val_binary_accuracy: 0.6600
# Epoch 221/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3722 - binary_accuracy: 0.8995 - val_loss: 0.6590 - val_binary_accuracy: 0.6600
# Epoch 222/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3728 - binary_accuracy: 0.8660 - val_loss: 0.6409 - val_binary_accuracy: 0.6800
# Epoch 223/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3696 - binary_accuracy: 0.8852 - val_loss: 0.6389 - val_binary_accuracy: 0.6600
# Epoch 224/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3692 - binary_accuracy: 0.8660 - val_loss: 0.5973 - val_binary_accuracy: 0.6800
# Epoch 225/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3681 - binary_accuracy: 0.8947 - val_loss: 0.6392 - val_binary_accuracy: 0.6600
# Epoch 226/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3663 - binary_accuracy: 0.8995 - val_loss: 0.6359 - val_binary_accuracy: 0.6800
# Epoch 227/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3690 - binary_accuracy: 0.8756 - val_loss: 0.6216 - val_binary_accuracy: 0.6600
# Epoch 228/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3660 - binary_accuracy: 0.8947 - val_loss: 0.6315 - val_binary_accuracy: 0.6600
# Epoch 229/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3664 - binary_accuracy: 0.8660 - val_loss: 0.6020 - val_binary_accuracy: 0.6800
# Epoch 230/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3713 - binary_accuracy: 0.8900 - val_loss: 0.6401 - val_binary_accuracy: 0.6800
# Epoch 231/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3617 - binary_accuracy: 0.8852 - val_loss: 0.6336 - val_binary_accuracy: 0.6800
# Epoch 232/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3639 - binary_accuracy: 0.8852 - val_loss: 0.6074 - val_binary_accuracy: 0.6600
# Epoch 233/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3599 - binary_accuracy: 0.8995 - val_loss: 0.6161 - val_binary_accuracy: 0.6600
# Epoch 234/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3594 - binary_accuracy: 0.8995 - val_loss: 0.6010 - val_binary_accuracy: 0.6800
# Epoch 235/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3588 - binary_accuracy: 0.9043 - val_loss: 0.6197 - val_binary_accuracy: 0.6600
# Epoch 236/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3582 - binary_accuracy: 0.9139 - val_loss: 0.6212 - val_binary_accuracy: 0.6600
# Epoch 237/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3573 - binary_accuracy: 0.8995 - val_loss: 0.6171 - val_binary_accuracy: 0.6600
# Epoch 238/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3550 - binary_accuracy: 0.8900 - val_loss: 0.5965 - val_binary_accuracy: 0.6800
# Epoch 239/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3574 - binary_accuracy: 0.8995 - val_loss: 0.6002 - val_binary_accuracy: 0.6600
# Epoch 240/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3554 - binary_accuracy: 0.9139 - val_loss: 0.6298 - val_binary_accuracy: 0.6800
# Epoch 241/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3563 - binary_accuracy: 0.8900 - val_loss: 0.6463 - val_binary_accuracy: 0.6600
# Epoch 242/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3536 - binary_accuracy: 0.9091 - val_loss: 0.6531 - val_binary_accuracy: 0.6600
# Epoch 243/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3525 - binary_accuracy: 0.8804 - val_loss: 0.6351 - val_binary_accuracy: 0.6800
# Epoch 244/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3497 - binary_accuracy: 0.8852 - val_loss: 0.5907 - val_binary_accuracy: 0.6800
# Epoch 245/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3518 - binary_accuracy: 0.8995 - val_loss: 0.6350 - val_binary_accuracy: 0.6800
# Epoch 246/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3479 - binary_accuracy: 0.8995 - val_loss: 0.6497 - val_binary_accuracy: 0.6600
# Epoch 247/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3475 - binary_accuracy: 0.8852 - val_loss: 0.5993 - val_binary_accuracy: 0.6600
# Epoch 248/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3441 - binary_accuracy: 0.9187 - val_loss: 0.6265 - val_binary_accuracy: 0.6800
# Epoch 249/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3434 - binary_accuracy: 0.8852 - val_loss: 0.5750 - val_binary_accuracy: 0.7000
# Epoch 250/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3488 - binary_accuracy: 0.9139 - val_loss: 0.5876 - val_binary_accuracy: 0.7000
# Epoch 251/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3425 - binary_accuracy: 0.9234 - val_loss: 0.6107 - val_binary_accuracy: 0.6600
# Epoch 252/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3412 - binary_accuracy: 0.9091 - val_loss: 0.6067 - val_binary_accuracy: 0.6600
# Epoch 253/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3427 - binary_accuracy: 0.9043 - val_loss: 0.6234 - val_binary_accuracy: 0.6800
# Epoch 254/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3400 - binary_accuracy: 0.9043 - val_loss: 0.6120 - val_binary_accuracy: 0.6600
# Epoch 255/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3386 - binary_accuracy: 0.9139 - val_loss: 0.6037 - val_binary_accuracy: 0.6600
# Epoch 256/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3379 - binary_accuracy: 0.9091 - val_loss: 0.6138 - val_binary_accuracy: 0.7000
# Epoch 257/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3346 - binary_accuracy: 0.9043 - val_loss: 0.5743 - val_binary_accuracy: 0.7000
# Epoch 258/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3374 - binary_accuracy: 0.9282 - val_loss: 0.6153 - val_binary_accuracy: 0.7000
# Epoch 259/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3326 - binary_accuracy: 0.9091 - val_loss: 0.5749 - val_binary_accuracy: 0.7000
# Epoch 260/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3350 - binary_accuracy: 0.9282 - val_loss: 0.5935 - val_binary_accuracy: 0.6800
# Epoch 261/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3323 - binary_accuracy: 0.9187 - val_loss: 0.5969 - val_binary_accuracy: 0.6600
# Epoch 262/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3301 - binary_accuracy: 0.9187 - val_loss: 0.5931 - val_binary_accuracy: 0.6800
# Epoch 263/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3314 - binary_accuracy: 0.9282 - val_loss: 0.5836 - val_binary_accuracy: 0.7000
# Epoch 264/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3317 - binary_accuracy: 0.9187 - val_loss: 0.5749 - val_binary_accuracy: 0.7000
# Epoch 265/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3285 - binary_accuracy: 0.9282 - val_loss: 0.5991 - val_binary_accuracy: 0.6800
# Epoch 266/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3262 - binary_accuracy: 0.9187 - val_loss: 0.5601 - val_binary_accuracy: 0.7000
# Epoch 267/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3283 - binary_accuracy: 0.9187 - val_loss: 0.5866 - val_binary_accuracy: 0.6800
# Epoch 268/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3244 - binary_accuracy: 0.9330 - val_loss: 0.6117 - val_binary_accuracy: 0.7200
# Epoch 269/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3255 - binary_accuracy: 0.9091 - val_loss: 0.5984 - val_binary_accuracy: 0.6600
# Epoch 270/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3235 - binary_accuracy: 0.9282 - val_loss: 0.6068 - val_binary_accuracy: 0.6600
# Epoch 271/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3243 - binary_accuracy: 0.9234 - val_loss: 0.5855 - val_binary_accuracy: 0.6600
# Epoch 272/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3222 - binary_accuracy: 0.9330 - val_loss: 0.6112 - val_binary_accuracy: 0.6800
# Epoch 273/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3221 - binary_accuracy: 0.9187 - val_loss: 0.5851 - val_binary_accuracy: 0.7000
# Epoch 274/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3196 - binary_accuracy: 0.9282 - val_loss: 0.5955 - val_binary_accuracy: 0.6600
# Epoch 275/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3182 - binary_accuracy: 0.9139 - val_loss: 0.5885 - val_binary_accuracy: 0.6800
# Epoch 276/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3212 - binary_accuracy: 0.9139 - val_loss: 0.5953 - val_binary_accuracy: 0.7000
# Epoch 277/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3170 - binary_accuracy: 0.9139 - val_loss: 0.6031 - val_binary_accuracy: 0.7200
# Epoch 278/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3160 - binary_accuracy: 0.9043 - val_loss: 0.5785 - val_binary_accuracy: 0.6800
# Epoch 279/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3155 - binary_accuracy: 0.9282 - val_loss: 0.5796 - val_binary_accuracy: 0.6800
# Epoch 280/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3156 - binary_accuracy: 0.9187 - val_loss: 0.5908 - val_binary_accuracy: 0.6800
# Epoch 281/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3141 - binary_accuracy: 0.9282 - val_loss: 0.5835 - val_binary_accuracy: 0.6800
# Epoch 282/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3132 - binary_accuracy: 0.9234 - val_loss: 0.5832 - val_binary_accuracy: 0.6800
# Epoch 283/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3109 - binary_accuracy: 0.9282 - val_loss: 0.5834 - val_binary_accuracy: 0.6800
# Epoch 284/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3099 - binary_accuracy: 0.9282 - val_loss: 0.5870 - val_binary_accuracy: 0.6800
# Epoch 285/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3084 - binary_accuracy: 0.9187 - val_loss: 0.5668 - val_binary_accuracy: 0.7000
# Epoch 286/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3115 - binary_accuracy: 0.9282 - val_loss: 0.5824 - val_binary_accuracy: 0.6800
# Epoch 287/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3086 - binary_accuracy: 0.9330 - val_loss: 0.5763 - val_binary_accuracy: 0.7000
# Epoch 288/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3084 - binary_accuracy: 0.9282 - val_loss: 0.5865 - val_binary_accuracy: 0.6800
# Epoch 289/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3076 - binary_accuracy: 0.9234 - val_loss: 0.5773 - val_binary_accuracy: 0.6800
# Epoch 290/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3048 - binary_accuracy: 0.9282 - val_loss: 0.5814 - val_binary_accuracy: 0.6800
# Epoch 291/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3030 - binary_accuracy: 0.9282 - val_loss: 0.5726 - val_binary_accuracy: 0.6800
# Epoch 292/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3033 - binary_accuracy: 0.9282 - val_loss: 0.5651 - val_binary_accuracy: 0.7000
# Epoch 293/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3022 - binary_accuracy: 0.9282 - val_loss: 0.5552 - val_binary_accuracy: 0.7000
# Epoch 294/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3026 - binary_accuracy: 0.9282 - val_loss: 0.5770 - val_binary_accuracy: 0.6800
# Epoch 295/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3006 - binary_accuracy: 0.9282 - val_loss: 0.5844 - val_binary_accuracy: 0.6800
# Epoch 296/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2984 - binary_accuracy: 0.9330 - val_loss: 0.5805 - val_binary_accuracy: 0.6800
# Epoch 297/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2968 - binary_accuracy: 0.9282 - val_loss: 0.5431 - val_binary_accuracy: 0.7200
# Epoch 298/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2986 - binary_accuracy: 0.9282 - val_loss: 0.5901 - val_binary_accuracy: 0.7000
# Epoch 299/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2966 - binary_accuracy: 0.9330 - val_loss: 0.5794 - val_binary_accuracy: 0.7000
# Epoch 300/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2958 - binary_accuracy: 0.9282 - val_loss: 0.5643 - val_binary_accuracy: 0.7000
# Epoch 301/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2960 - binary_accuracy: 0.9330 - val_loss: 0.5503 - val_binary_accuracy: 0.7000
# Epoch 302/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2974 - binary_accuracy: 0.9282 - val_loss: 0.5734 - val_binary_accuracy: 0.6800
# Epoch 303/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2931 - binary_accuracy: 0.9426 - val_loss: 0.5827 - val_binary_accuracy: 0.6800
# Epoch 304/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2930 - binary_accuracy: 0.9330 - val_loss: 0.5978 - val_binary_accuracy: 0.7200
# Epoch 305/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2919 - binary_accuracy: 0.9330 - val_loss: 0.5684 - val_binary_accuracy: 0.7000
# Epoch 306/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2919 - binary_accuracy: 0.9234 - val_loss: 0.5692 - val_binary_accuracy: 0.6800
# Epoch 307/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2898 - binary_accuracy: 0.9378 - val_loss: 0.6072 - val_binary_accuracy: 0.7200
# Epoch 308/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2905 - binary_accuracy: 0.9282 - val_loss: 0.5834 - val_binary_accuracy: 0.6800
# Epoch 309/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2886 - binary_accuracy: 0.9330 - val_loss: 0.5673 - val_binary_accuracy: 0.6800
# Epoch 310/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2863 - binary_accuracy: 0.9426 - val_loss: 0.5527 - val_binary_accuracy: 0.7000
# Epoch 311/500
# ...
# Epoch 399/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2181 - binary_accuracy: 0.9617 - val_loss: 0.5733 - val_binary_accuracy: 0.7000
# Epoch 400/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2181 - binary_accuracy: 0.9617 - val_loss: 0.5397 - val_binary_accuracy: 0.7200
# Epoch 401/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2191 - binary_accuracy: 0.9665 - val_loss: 0.5312 - val_binary_accuracy: 0.7400
# Epoch 402/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2171 - binary_accuracy: 0.9761 - val_loss: 0.5476 - val_binary_accuracy: 0.7000
# Epoch 403/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2164 - binary_accuracy: 0.9665 - val_loss: 0.5393 - val_binary_accuracy: 0.7200
# Epoch 404/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2144 - binary_accuracy: 0.9713 - val_loss: 0.5376 - val_binary_accuracy: 0.7200
# Epoch 405/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2145 - binary_accuracy: 0.9665 - val_loss: 0.5900 - val_binary_accuracy: 0.7200
# Epoch 406/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2163 - binary_accuracy: 0.9665 - val_loss: 0.5979 - val_binary_accuracy: 0.7200
# Epoch 407/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2158 - binary_accuracy: 0.9665 - val_loss: 0.5397 - val_binary_accuracy: 0.7200
# Epoch 408/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2134 - binary_accuracy: 0.9713 - val_loss: 0.5601 - val_binary_accuracy: 0.7200
# Epoch 409/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2121 - binary_accuracy: 0.9665 - val_loss: 0.5551 - val_binary_accuracy: 0.7200
# Epoch 410/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2115 - binary_accuracy: 0.9617 - val_loss: 0.5483 - val_binary_accuracy: 0.7200
# Epoch 411/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2110 - binary_accuracy: 0.9713 - val_loss: 0.5544 - val_binary_accuracy: 0.7200
# Epoch 412/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2155 - binary_accuracy: 0.9617 - val_loss: 0.5515 - val_binary_accuracy: 0.7200
# Epoch 413/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2104 - binary_accuracy: 0.9713 - val_loss: 0.5372 - val_binary_accuracy: 0.7200
# Epoch 414/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2093 - binary_accuracy: 0.9665 - val_loss: 0.5373 - val_binary_accuracy: 0.7200
# Epoch 415/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2076 - binary_accuracy: 0.9665 - val_loss: 0.5244 - val_binary_accuracy: 0.7200
# Epoch 416/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2080 - binary_accuracy: 0.9713 - val_loss: 0.5559 - val_binary_accuracy: 0.7200
# Epoch 417/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2104 - binary_accuracy: 0.9569 - val_loss: 0.5550 - val_binary_accuracy: 0.7000
# Epoch 418/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2061 - binary_accuracy: 0.9713 - val_loss: 0.5233 - val_binary_accuracy: 0.7400
# Epoch 419/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2060 - binary_accuracy: 0.9713 - val_loss: 0.5267 - val_binary_accuracy: 0.7400
# Epoch 420/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2062 - binary_accuracy: 0.9713 - val_loss: 0.5222 - val_binary_accuracy: 0.7400
# Epoch 421/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2060 - binary_accuracy: 0.9713 - val_loss: 0.5364 - val_binary_accuracy: 0.7400
# Epoch 422/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2042 - binary_accuracy: 0.9665 - val_loss: 0.5322 - val_binary_accuracy: 0.7400
# Epoch 423/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2034 - binary_accuracy: 0.9713 - val_loss: 0.5481 - val_binary_accuracy: 0.7200
# Epoch 424/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2012 - binary_accuracy: 0.9761 - val_loss: 0.5170 - val_binary_accuracy: 0.7400
# Epoch 425/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2056 - binary_accuracy: 0.9713 - val_loss: 0.5167 - val_binary_accuracy: 0.7400
# Epoch 426/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2017 - binary_accuracy: 0.9809 - val_loss: 0.5266 - val_binary_accuracy: 0.7400
# Epoch 427/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2020 - binary_accuracy: 0.9713 - val_loss: 0.5367 - val_binary_accuracy: 0.7400
# Epoch 428/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2025 - binary_accuracy: 0.9665 - val_loss: 0.5461 - val_binary_accuracy: 0.7200
# Epoch 429/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1995 - binary_accuracy: 0.9761 - val_loss: 0.5627 - val_binary_accuracy: 0.7000
# Epoch 430/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1992 - binary_accuracy: 0.9809 - val_loss: 0.5742 - val_binary_accuracy: 0.7200
# Epoch 431/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1984 - binary_accuracy: 0.9761 - val_loss: 0.5519 - val_binary_accuracy: 0.7400
# Epoch 432/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1964 - binary_accuracy: 0.9761 - val_loss: 0.5275 - val_binary_accuracy: 0.7400
# Epoch 433/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1995 - binary_accuracy: 0.9761 - val_loss: 0.5133 - val_binary_accuracy: 0.7200
# Epoch 434/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2001 - binary_accuracy: 0.9761 - val_loss: 0.5182 - val_binary_accuracy: 0.7200
# Epoch 435/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2012 - binary_accuracy: 0.9665 - val_loss: 0.5486 - val_binary_accuracy: 0.7400
# Epoch 436/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1949 - binary_accuracy: 0.9761 - val_loss: 0.5793 - val_binary_accuracy: 0.7200
# Epoch 437/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1943 - binary_accuracy: 0.9761 - val_loss: 0.5576 - val_binary_accuracy: 0.7400
# Epoch 438/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1950 - binary_accuracy: 0.9761 - val_loss: 0.5053 - val_binary_accuracy: 0.7400
# Epoch 439/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1992 - binary_accuracy: 0.9713 - val_loss: 0.5397 - val_binary_accuracy: 0.7200
# Epoch 440/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1921 - binary_accuracy: 0.9713 - val_loss: 0.5127 - val_binary_accuracy: 0.7200
# Epoch 441/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1951 - binary_accuracy: 0.9809 - val_loss: 0.5511 - val_binary_accuracy: 0.7400
# Epoch 442/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1914 - binary_accuracy: 0.9761 - val_loss: 0.5405 - val_binary_accuracy: 0.7600
# Epoch 443/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1919 - binary_accuracy: 0.9761 - val_loss: 0.5165 - val_binary_accuracy: 0.7200
# Epoch 444/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1914 - binary_accuracy: 0.9809 - val_loss: 0.5323 - val_binary_accuracy: 0.7400
# Epoch 445/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1898 - binary_accuracy: 0.9761 - val_loss: 0.5362 - val_binary_accuracy: 0.7200
# Epoch 446/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1914 - binary_accuracy: 0.9761 - val_loss: 0.5486 - val_binary_accuracy: 0.7400
# Epoch 447/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1887 - binary_accuracy: 0.9809 - val_loss: 0.5596 - val_binary_accuracy: 0.7000
# Epoch 448/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1875 - binary_accuracy: 0.9809 - val_loss: 0.5488 - val_binary_accuracy: 0.7600
# Epoch 449/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1869 - binary_accuracy: 0.9761 - val_loss: 0.5267 - val_binary_accuracy: 0.7400
# Epoch 450/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1864 - binary_accuracy: 0.9761 - val_loss: 0.5160 - val_binary_accuracy: 0.7200
# Epoch 451/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1888 - binary_accuracy: 0.9809 - val_loss: 0.5487 - val_binary_accuracy: 0.7400
# Epoch 452/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1860 - binary_accuracy: 0.9809 - val_loss: 0.5524 - val_binary_accuracy: 0.7400
# Epoch 453/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1853 - binary_accuracy: 0.9856 - val_loss: 0.5512 - val_binary_accuracy: 0.7400
# Epoch 454/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1859 - binary_accuracy: 0.9761 - val_loss: 0.5260 - val_binary_accuracy: 0.7400
# Epoch 455/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1859 - binary_accuracy: 0.9809 - val_loss: 0.5471 - val_binary_accuracy: 0.7400
# Epoch 456/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1847 - binary_accuracy: 0.9856 - val_loss: 0.5695 - val_binary_accuracy: 0.7200
# Epoch 457/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1845 - binary_accuracy: 0.9713 - val_loss: 0.5167 - val_binary_accuracy: 0.7200
# Epoch 458/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1841 - binary_accuracy: 0.9809 - val_loss: 0.5365 - val_binary_accuracy: 0.7600
# Epoch 459/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1852 - binary_accuracy: 0.9856 - val_loss: 0.5389 - val_binary_accuracy: 0.7600
# Epoch 460/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1819 - binary_accuracy: 0.9809 - val_loss: 0.5324 - val_binary_accuracy: 0.7600
# Epoch 461/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1827 - binary_accuracy: 0.9856 - val_loss: 0.5610 - val_binary_accuracy: 0.7200
# Epoch 462/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1805 - binary_accuracy: 0.9761 - val_loss: 0.5308 - val_binary_accuracy: 0.7400
# Epoch 463/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1794 - binary_accuracy: 0.9856 - val_loss: 0.5511 - val_binary_accuracy: 0.7400
# Epoch 464/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1785 - binary_accuracy: 0.9761 - val_loss: 0.5142 - val_binary_accuracy: 0.7200
# Epoch 465/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1786 - binary_accuracy: 0.9761 - val_loss: 0.5322 - val_binary_accuracy: 0.7400
# Epoch 466/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1798 - binary_accuracy: 0.9809 - val_loss: 0.5310 - val_binary_accuracy: 0.7200
# Epoch 467/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1780 - binary_accuracy: 0.9809 - val_loss: 0.5218 - val_binary_accuracy: 0.7200
# Epoch 468/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1786 - binary_accuracy: 0.9904 - val_loss: 0.5546 - val_binary_accuracy: 0.7600
# Epoch 469/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1765 - binary_accuracy: 0.9809 - val_loss: 0.5443 - val_binary_accuracy: 0.7600
# Epoch 470/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1760 - binary_accuracy: 0.9809 - val_loss: 0.5679 - val_binary_accuracy: 0.7200
# Epoch 471/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1778 - binary_accuracy: 0.9809 - val_loss: 0.5420 - val_binary_accuracy: 0.7600
# Epoch 472/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1737 - binary_accuracy: 0.9904 - val_loss: 0.5610 - val_binary_accuracy: 0.7400
# Epoch 473/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1742 - binary_accuracy: 0.9761 - val_loss: 0.5226 - val_binary_accuracy: 0.7200
# Epoch 474/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1741 - binary_accuracy: 0.9856 - val_loss: 0.5315 - val_binary_accuracy: 0.7400
# Epoch 475/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1732 - binary_accuracy: 0.9856 - val_loss: 0.5420 - val_binary_accuracy: 0.7600
# Epoch 476/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1722 - binary_accuracy: 0.9856 - val_loss: 0.5326 - val_binary_accuracy: 0.7400
# Epoch 477/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1741 - binary_accuracy: 0.9856 - val_loss: 0.5601 - val_binary_accuracy: 0.7600
# Epoch 478/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1707 - binary_accuracy: 0.9856 - val_loss: 0.5447 - val_binary_accuracy: 0.7400
# Epoch 479/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1725 - binary_accuracy: 0.9809 - val_loss: 0.5558 - val_binary_accuracy: 0.7400
# Epoch 480/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1715 - binary_accuracy: 0.9761 - val_loss: 0.5655 - val_binary_accuracy: 0.7200
# Epoch 481/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1718 - binary_accuracy: 0.9761 - val_loss: 0.5415 - val_binary_accuracy: 0.7600
# Epoch 482/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1690 - binary_accuracy: 0.9809 - val_loss: 0.5276 - val_binary_accuracy: 0.7200
# Epoch 483/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1690 - binary_accuracy: 0.9856 - val_loss: 0.5354 - val_binary_accuracy: 0.7600
# Epoch 484/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1684 - binary_accuracy: 0.9904 - val_loss: 0.5541 - val_binary_accuracy: 0.7600
# Epoch 485/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1669 - binary_accuracy: 0.9809 - val_loss: 0.5424 - val_binary_accuracy: 0.7600
# Epoch 486/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1667 - binary_accuracy: 0.9904 - val_loss: 0.5616 - val_binary_accuracy: 0.7600
# Epoch 487/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1664 - binary_accuracy: 0.9809 - val_loss: 0.5164 - val_binary_accuracy: 0.7400
# Epoch 488/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1692 - binary_accuracy: 0.9856 - val_loss: 0.5286 - val_binary_accuracy: 0.7200
# Epoch 489/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1674 - binary_accuracy: 0.9904 - val_loss: 0.5499 - val_binary_accuracy: 0.7600
# Epoch 490/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1656 - binary_accuracy: 0.9809 - val_loss: 0.5496 - val_binary_accuracy: 0.7600
# Epoch 491/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1650 - binary_accuracy: 0.9856 - val_loss: 0.5634 - val_binary_accuracy: 0.7400
# Epoch 492/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1643 - binary_accuracy: 0.9809 - val_loss: 0.5486 - val_binary_accuracy: 0.7600
# Epoch 493/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1658 - binary_accuracy: 0.9856 - val_loss: 0.5300 - val_binary_accuracy: 0.7200
# Epoch 494/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1637 - binary_accuracy: 0.9904 - val_loss: 0.5295 - val_binary_accuracy: 0.7200
# Epoch 495/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1648 - binary_accuracy: 0.9904 - val_loss: 0.5325 - val_binary_accuracy: 0.7600
# Epoch 496/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1615 - binary_accuracy: 0.9856 - val_loss: 0.5384 - val_binary_accuracy: 0.7600
# Epoch 497/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1618 - binary_accuracy: 0.9904 - val_loss: 0.5720 - val_binary_accuracy: 0.7000
# Epoch 498/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1618 - binary_accuracy: 0.9809 - val_loss: 0.5558 - val_binary_accuracy: 0.7600
# Epoch 499/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1634 - binary_accuracy: 0.9809 - val_loss: 0.5529 - val_binary_accuracy: 0.7600
# Epoch 500/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1604 - binary_accuracy: 0.9856 - val_loss: 0.5281 - val_binary_accuracy: 0.7200
# Training: ends at 2020-09-21 16:12:00
# Duration: 24.066415071487427s

# %%
loss, acc = model.evaluate(x=train_x,y=train_y, batch_size=32)
print('Train loss: %.4f - acc: %.4f' % (loss, acc))

loss_, acc_ = model.evaluate(x=test_x,y=test_y, batch_size=32)
print('Test loss: %.4f - acc: %.4f' % (loss_, acc_))
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 1.7148e-04 - binary_accuracy: 1.0000
# Train loss: 0.0002 - acc: 1.0000
# 2/2 [==============================] - 0s 3ms/step - loss: 2.8979 - binary_accuracy: 0.7400
# Test loss: 2.8979 - acc: 0.7400

# %% [markdown]
# # 2.0 Hyperparameter Tuning

# %% [markdown]
# The [Keras Tuner](https://github.com/keras-team/keras-tuner) is a library that helps you pick the optimal set of hyperparameters for your TensorFlow program. The process of selecting the right set of hyperparameters for your machine learning (ML) application is called **hyperparameter tuning** or **hypertuning**.
#
# Hyperparameters are the variables that govern the training process and the topology of an ML model. These variables remain constant over the training process and directly impact the performance of your ML program. Hyperparameters are of two types:
# 1. **Model hyperparameters** which influence model selection such as the number and width of hidden layers
# 2. **Algorithm hyperparameters** which influence the speed and quality of the learning algorithm such as the learning rate for Stochastic Gradient Descent (SGD) and the number of nearest neighbors for a k Nearest Neighbors (KNN) classifier

# %% [markdown]
# ## 2.1 Define the model
#
# When you build a model for hypertuning, you also define the hyperparameter search space in addition to the model architecture. The model you set up for hypertuning is called a **hypermodel**.
#
# You can define a hypermodel through two approaches:
#
# * By using a model builder function
# * By subclassing the `HyperModel` class of the Keras Tuner API
#
# You can also use two pre-defined `HyperModel` classes - [HyperXception](https://keras-team.github.io/keras-tuner/documentation/hypermodels/#hyperxception-class) and [HyperResNet](https://keras-team.github.io/keras-tuner/documentation/hypermodels/#hyperresnet-class) for computer vision applications.
#
# In this section, you use a model builder function to define the image classification model. The model builder function returns a compiled model and uses hyperparameters you define inline to hypertune the model.

# %%
def model_builder(hp):
  # Instantiate a simple classification model
  model = tf.keras.Sequential()

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 8-32
  hp_units = hp.Int('units', min_value = 8, max_value = 32, step = 8)
  model.add(tf.keras.layers.Dense(hp_units, activation=tf.nn.relu, dtype='float64'))
  
  model.add(tf.keras.layers.Dense(8, activation=tf.nn.relu, dtype='float64'))
  model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, dtype='float64'))

  # Instantiate a logistic loss function that expects integer targets.
  loss = tf.keras.losses.BinaryCrossentropy()

  # Instantiate an accuracy metric.
  accuracy = tf.keras.metrics.BinaryAccuracy()

  # Instantiate an optimizer.
  optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

  # configure the optimizer, loss, and metrics to monitor.
  model.compile(optimizer=optimizer, loss=loss, metrics=[accuracy])

  return model

# %% [markdown]
# ## 2.2 Instantiate the tuner and perform hypertuning

# %% [markdown]
# Instantiate the tuner to perform the hypertuning. The Keras Tuner has [four tuners available](https://keras-team.github.io/keras-tuner/documentation/tuners/) - `RandomSearch`, `Hyperband`, `BayesianOptimization`, and `Sklearn`.
#
# Notice that in previous subsection we're not fitting there, and we're returning the compiled model. Let's continue to build out the rest of our program first, then we'll make things more dynamic. Adding the dynamic bits will all happen in the **model_builder** function, but we will need some other code that will use this function now.  To start, we're going to import **RandomSearch** and after that we'll first define our tuner.

# %%
from kerastuner.tuners import RandomSearch

# %%
# path to store results
LOG_DIR = f"{int(time.time())}"

# %%
tuner = RandomSearch(model_builder,
                     objective='val_binary_accuracy',
                     max_trials=4,  # how many model configurations would you like to test?
                     executions_per_trial=1,  # how many trials per variation? (same model could perform differently)
                     directory=LOG_DIR,
                     project_name="my_first_tuner"
                     )

# %% [markdown]
# - Your objective here probably should be **validation accuracy**, but you can choose from other things like **val_loss** for example.
# - **max_trials** allows you limit how many tests will be run. If you put 10 here, you will get 10 different tests (provided you've specified enough variability for 10 different combinations, anyway).
# - **executions_per_trial** might be 1, but you might also do many more like 3,5, or even 10.
#
# Basically, if you're just hunting for a model that works, then you should just do 1 trial per variation. If you're attempting to seek out 1-3% on **validation accuracy**, then you should run 3+ trials most likely per model, because each time a model runs, you should see some variation in final values. So this will just depend on what kind of a search you're doing (just trying to find something that works vs fine tuning...or anything in between).

# %% [markdown]
# Run the hyperparameter search. The arguments for the search method are the same as those used for [`tf.keras.model.fit`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit).
#
# Before running the hyperparameter search, define a callback to clear the training outputs at the end of every training step.

# %%
class ClearTrainingOutput(tf.keras.callbacks.Callback):
  def on_train_end(*args, **kwargs):
    IPython.display.clear_output(wait = True)

# %%
tuner.search(train_x,
             train_y, 
             epochs = 500, 
             verbose=1,
             batch_size=32,
             validation_data = (test_x, test_y),
             callbacks = [ClearTrainingOutput()])
# Out:
# Trial 3 Complete [00h 00m 22s]
# val_binary_accuracy: 0.7799999713897705
#
# Best val_binary_accuracy So Far: 0.800000011920929
# Total elapsed time: 00h 01m 08s
# INFO:tensorflow:Oracle triggered exit

# %%
# print a summary of results
tuner.results_summary(num_trials=10)
# Out:
# Results summary
# Results in 1600716606/my_first_tuner
# Showing 10 best trials
# Objective(name='val_binary_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# units: 24
# Score: 0.800000011920929
# Trial summary
# Hyperparameters:
# units: 8
# Score: 0.7799999713897705
# Trial summary
# Hyperparameters:
# units: 16
# Score: 0.699999988079071

# %%
# best hyperparameters is a dictionary
tuner.get_best_hyperparameters()[0].values
# Out:
# {'units': 24}

# %%
# search space summary
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 1
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 32, 'step': 8, 'sampling': None}

# %%
print(f"""The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {tuner.get_best_hyperparameters()[0].values.get('units')}""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 24

# %% [markdown]
# ## 2.3 Playing with search space

# %% [markdown]
# We also can play with the search space in order to contain conditional hyperparameters. Below, we have a **for loop** creating a **tunable number of layers**, which themselves involve a tunable **units** parameter. This can be pushed to any level of parameter interdependency, including recursion. Note that all parameter names should be unique (here, in the loop over **i**, we name the inner parameters **'units_'** + **str(i)**).

# %%
def model_builder_all(hp):
  # Instantiate a simple classification model
  model = tf.keras.Sequential()
  
  # Create a tunable number of layers 1,2,3,4
  for i in range(hp.Int('num_layers', 1, 4)):

    # Tune the number of units in the Dense layer
    # Choose an optimal value between 8-32
    model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
                                        min_value = 8,
                                        max_value = 32,
                                        step = 8),
                                    # Tune the activation functions
                                    activation= hp.Choice('dense_activation_' + str(i),
                                                          values=['relu', 'tanh'],
                                                          default='relu'),
                                    dtype='float64'))

  model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid, dtype='float64'))

  # Instantiate a logistic loss function that expects integer targets.
  loss = tf.keras.losses.BinaryCrossentropy()

  # Instantiate an accuracy metric.
  accuracy = tf.keras.metrics.BinaryAccuracy()

  optimizer = hp.Choice('optimizer', ['adam', 'SGD'])
  if optimizer == 'adam':
    opt = tf.keras.optimizers.Adam(learning_rate=hp.Float('lrate_adam',
                                                          min_value=1e-4,
                                                          max_value=1e-2, 
                                                          sampling='LOG'))
  else:
    opt = tf.keras.optimizers.SGD(learning_rate=hp.Float('lrate_sgd',
                                                          min_value=1e-4,
                                                          max_value=1e-2, 
                                                          sampling='LOG'))

  # configure the optimizer, loss, and metrics to monitor.
  model.compile(optimizer=opt, loss=loss, metrics=[accuracy])

  return model

# %%
# path to store results
LOG_DIR = f"{int(time.time())}"

# %%
tuner_ = RandomSearch(model_builder_all,
                     objective='val_binary_accuracy',
                     max_trials=20,  # how many model configurations would you like to test?
                     executions_per_trial=1,  # how many trials per variation? (same model could perform differently)
                     directory=LOG_DIR,
                     project_name="my_first_tuner"
                     )

# %%
tuner_.search(train_x,
             train_y, 
             epochs = 500,
             # verbose = 0 (silent) 
             verbose=0,
             batch_size=32,
             validation_data = (test_x, test_y),
             callbacks = [ClearTrainingOutput()])
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner_.results_summary()

# %%
tuner_.get_best_hyperparameters()[0].values

# %%
tuner_.search_space_summary()

# %% [markdown]
# ## 2.4 Retrain the model with the optimal hyperparameters

# %%
# Build the model with the optimal hyperparameters and train it on the data
best_hps = tuner_.get_best_hyperparameters()[0]
model = tuner_.hypermodel.build(best_hps)
model.fit(train_x, train_y, epochs = 500, validation_data = (test_x, test_y),batch_size=32)

# %%
loss_, acc_ = model.evaluate(x=test_x,y=test_y, batch_size=32)
print('Test loss: %.3f - acc: %.3f' % (loss_, acc_))

# %%
model.summary()

# %% [markdown]
# <mark>Exercise</mark>
#
# Hyperparameter tuning is a time-consuming task. The previous result was not so good. You can try to improve it the tuning considering:
# - Other [Tuners](https://keras-team.github.io/keras-tuner/documentation/tuners/): BayesianOptimization, Hyperband
# - Evaluate **max_trials** ranges over 100 or more?
# - **executions_per_trial** values in [2,3]?
# - How about you write an article on Medium about Keras Tuner?

# %%
# PUT YOUR CODE HERE

# %% [markdown]
# # 3.0 References

# %% [markdown]
# 1. https://www.kaggle.com/fchollet/moa-keras-kerastuner-best-practices/
# 2. https://www.kaggle.com/fchollet/titanic-keras-kerastuner-best-practices
# 3. https://www.kaggle.com/fchollet/keras-kerastuner-best-practices
# 4. https://pythonprogramming.net/keras-tuner-optimizing-neural-network-tutorial/
# 5. https://github.com/keras-team/keras-tuner
# 6. https://machinelearningmastery.com/autokeras-for-classification-and-regression/
